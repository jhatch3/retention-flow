# %% [markdown]
# # DistilBERT — Email Quality Classifier
#
# Fine-tuning DistilBERT (PyTorch + Hugging Face) to grade generated retention
# emails on a 1-5 quality scale. This is **tier 1** of the two-tier eval stack —
# the fast, local classifier that scores every email before the LLM judge.
#
# The reproducible fine-tuning run lives in `src/backend/eval/distilbert/train.py`;
# this notebook is for exploration and error analysis.
#
# **Prerequisite:** the Claude-generated corpus
# `src/backend/eval/distilbert/dataset/email_quality.jsonl` exists.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent / "src"))

# %% [markdown]
# ## 1. Load the email-quality corpus

# %% [markdown]
# ## 2. Tokenize

# %% [markdown]
# ## 3. Fine-tune DistilBERT

# %% [markdown]
# ## 4. Evaluate

# %% [markdown]
# ## 5. Error analysis — confusion matrix
#
# Where does the classifier disagree with the labels, and is the disagreement
# concentrated on adjacent grades (3 vs 4) or far apart (1 vs 5)?

# %% [markdown]
# ## 6. Reproducible run
#
# The reproducible fine-tuning run lives in
# `src/backend/eval/distilbert/train.py`, which fine-tunes, evaluates, logs
# metrics, and registers the model in MLflow (`logs/mlruns/`):
#
# ```
# python -m backend.eval.distilbert.train
# ```
