# %%
import sys
from pathlib import Path

# Notebook is at src/ai/prompt_testing.ipynb
# We want the repo root on sys.path so `src.ai.xxx` resolves
sys.path.insert(0, str(Path.cwd().parent.parent))

from src.ai.prompts.test_dataset import test_input_service_failure, TEST_CASES
from src.ai.prompts.RETENTION_EMAIL_SYSTEM_PROMPT import RETENTION_EMAIL_SYSTEM_PROMPT
from claude import run_conversation
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[37], line 8
#       4 # Notebook is at src/ai/prompt_testing.ipynb
#       5 # We want the repo root on sys.path so `src.ai.xxx` resolves
#       6 sys.path.insert(0, str(Path.cwd().parent.parent))
# ----> 8 from src.ai.prompts.test_dataset import test_input_service_failure, TEST_CASES
#       9 from src.ai.prompts.RETENTION_EMAIL_SYSTEM_PROMPT import RETENTION_EMAIL_SYSTEM_PROMPT
#      10 from claude import run_conversation
#
# ImportError: cannot import name 'TEST_CASES' from 'src.ai.prompts.test_dataset' (c:\Users\Justin\retention-flow\src\ai\prompts\test_dataset.py)

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 from src.ai.prompts.test_dataset import test_input_service_failure, TEST_CASES
#       2 from src.ai.prompts.test_dataset import test_input_service_failure
#       4 try:
#
# ImportError: cannot import name 'TEST_CASES' from 'src.ai.prompts.test_dataset' (c:\Users\Justin\retention-flow\src\ai\prompts\test_dataset.py)
